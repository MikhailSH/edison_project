# %%
from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ydata_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
# Импортируем библиотеки
import numpy as np  # Импортируем библиотеку NumPy и присваиваем ей псевдоним np
import pandas as pd  # Импортируем библиотеку pandas и присваиваем ей псевдоним pd
from pandas_profiling import ProfileReport  # Импортируем функцию ProfileReport из библиотеки pandas_profiling

# Создадим DataFrame со случайными данными
df = pd.DataFrame(
    np.random.rand(100, 5),  # Генерируем случайные числа в форме 100x5 с помощью NumPy
    columns=['a', 'b', 'c', 'd', 'e']  # Зададим названия столбцов DataFrame
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Импортируем библиотеки
#       2 import numpy as np  # Импортируем библиотеку NumPy и присваиваем ей псевдоним np
#       3 import pandas as pd  # Импортируем библиотеку pandas и присваиваем ей псевдоним pd
# ----> 4 from pandas_profiling import ProfileReport  # Импортируем функцию ProfileReport из библиотеки pandas_profiling
#       5
#       6 # Создадим DataFrame со случайными данными
#       7 df = pd.DataFrame(
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %% [markdown]
# Цель работы: провести полноценный анализ данных одного из реальных источников данных с помощью Python и библиотек для анализа данных.

# %%
#загрузка данных
df = pd.read_csv('C:/Users/omaka/heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
profile = ProfileReport(df,
                        title='Pandas Profiling Report')

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-08-27 11:40:36.670511&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file("output2.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
