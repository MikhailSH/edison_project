# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('salary_data.csv')
data.head()
print(data.describe())
mean = np.mean(data.salary)
print("Средняя зарплата: ", mean)
median = np.median(data.salary),
print("Медиана зарплаты: ",median)
plt.figure(figsize=(8, 6))
plt.hist(data['salary'], bins=10, edgecolor='black')
plt.xlabel('Зарплата')
plt.ylabel('Частота')
plt.title('Распределение зарплат')
plt.show()
# Out:
#             salary
# count    10.000000
# mean   3690.000000
# std    1121.952663
# min    2000.000000
# 25%    2775.000000
# 50%    3750.000000
# 75%    4475.000000
# max    5300.000000
# Средняя зарплата:  3690.0
# Медиана зарплаты:  (np.float64(3750.0),)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из CSV-файла
data = pd.read_csv('salary_data.csv')

# Рассчет среднего значения и медианы
mean_salary = data['salary'].mean()
median_salary = data['salary'].median()

# Визуализация распределения зарплат
plt.figure(figsize=(8, 6))
plt.hist(data['salary'], bins=10, edgecolor='black')
plt.xlabel('Зарплата')
plt.ylabel('Частота')
plt.title('Распределение зарплат')
plt.show()

# Вывод результатов
print("Средняя зарплата: ", mean_salary)
print("Медиана зарплаты: ", median_salary)
# Out:
# Средняя зарплата:  3690.0
# Медиана зарплаты:  3750.0
