# %%
import numpy as np  # Импортируем библиотеку NumPy и присваиваем ей псевдоним np
import pandas as pd
df1 = pd.read_csv('data11.csv')
df2 = pd.read_csv('data22.csv')
df3 = pd.read_csv('data33.csv')
df1.head()
df1.info()
df1.shape
df2.head()
df2.info()
df2.shape
df3.head()
df3.info()
df3.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      3 non-null      int64
#  1   Name    3 non-null      str
#  2   Age     3 non-null      int64
#  3   Salary  3 non-null      int64
# dtypes: int64(3), str(1)
# memory usage: 228.0 bytes
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3 non-null      str
#  1   Open    3 non-null      float64
#  2   High    3 non-null      int64
#  3   Low     3 non-null      int64
#  4   Close   3 non-null      int64
#  5   Volume  3 non-null      int64
# dtypes: float64(1), int64(4), str(1)
# memory usage: 276.0 bytes
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ...

# %%
taxonomy = {
    'df1': df1.dtypes,
    'df2': df2.dtypes,
    'df3': df3.dtypes }

for dataset, dtypes in taxonomy.items():
    print("Таксономия данных для", dataset)
    print(dtypes)
    print()
# Out:
# Таксономия данных для df1
# ID        int64
# Name        str
# Age       int64
# Salary    int64
# dtype: object
#
# Таксономия данных для df2
# Date          str
# Open      float64
# High        int64
# Low         int64
# Close       int64
# Volume      int64
# dtype: object
#
# Таксономия данных для df3
# Country           str
# City              str
# Population      int64
# Area          float64
# dtype: object
